# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_california_housing as fch

# %%
fch
# Out:
# <function sklearn.datasets._california_housing.fetch_california_housing(*, data_home=None, download_if_missing=True, return_X_y=False, as_frame=False, n_retries=3, delay=1.0)>

# %%
df = fch(as_frame=True).frame
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
matrix = df.corr()
matrix
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge    -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms     0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms   -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population   0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup     0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude    -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude   -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# MedHouseVal  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.079809  -0.015176     0.688075
# HouseAge     0.011173  -0.108197     0.105623
# AveRooms     0.106389  -0.027540     0.151948
# AveBedrms    0.069721   0.013344    -0.046701
# Population  -0.108785   0.099773    -0.024650
# AveOccup     0.002366   0.002476    -0.023737
# Latitude     1.000000  -0.924664    -0.144160
# Longitude   -0.924664   1.000000    -0.045967
# MedHouseVal -0.144160  -0.045967     1.000000

# %%
plt.figure(figsize=(10,9))
sns.heatmap(matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title(" correlation of matrix ")
plt.show()

# %%
dt = df.sample(n=1000)
dt
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 16298  2.6250      31.0  4.416667   0.934524      1163.0  3.461310     37.96
# 4202   3.1330      33.0  4.310231   1.066007      2496.0  4.118812     34.11
# 13181  5.2280      16.0  6.569451   1.019278      6931.0  3.426100     33.97
# 5676   3.7596      36.0  4.497848   1.070301      1815.0  2.604017     33.71
# 16946  6.1349      33.0  6.893417   0.978056       827.0  2.592476     37.55
# ...       ...       ...       ...        ...         ...       ...       ...
# 6894   5.9941      23.0  6.495274   1.068053      1729.0  3.268431     34.05
# 9465   2.9243      35.0  5.745819   1.153846       698.0  2.334448     39.46
# 5772   3.0199      25.0  4.067385   1.086253      2205.0  2.971698     34.15
# 5844   3.1051      23.0  3.731289   1.031705      4757.0  2.472453     34.20
# 2745   3.6042      34.0  5.538462   1.000000       621.0  2.985577     32.79
#
#        Longitude  MedHouseVal
# 16298    -121.22      0.72100
# 4202     -118.23      1.56000
# 13181    -117.72      1.87800
# 5676     -118.29      3.00000
# 16946    -122.33      5.00001
# ...          ...          ...
# 6894     -118.11      2.66700
# 9465     -123.80      1.31600
# 5772     -118.27      2.20200
# 5844     -118.33      2.06500
# 2745     -115.57      0.73600
#
# [1000 rows x 9 columns]

# %%
sns.pairplot(dt, diag_kind='kde', plot_kws={'alpha': 0.51})
plt.suptitle("Pairplot of california housing dataset", y = 1.02)
plt.show()
