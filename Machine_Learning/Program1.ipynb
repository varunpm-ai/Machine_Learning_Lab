# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import sklearn as sk
from sklearn.datasets import fetch_california_housing as fch

# %%
fch
# Out:
# <function sklearn.datasets._california_housing.fetch_california_housing(*, data_home=None, download_if_missing=True, return_X_y=False, as_frame=False, n_retries=3, delay=1.0)>

# %%
data = fch(as_frame=True)
df = data.frame

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
for i, col in enumerate(df.columns):
    print(i, col)
# Out:
# 0 MedInc
# 1 HouseAge
# 2 AveRooms
# 3 AveBedrms
# 4 Population
# 5 AveOccup
# 6 Latitude
# 7 Longitude
# 8 MedHouseVal

# %%
print(" Dataset Shape : ", df.shape)
print(" Dataset Colums : ", df.columns)
# Out:
#  Dataset Shape :  (20640, 9)
#  Dataset Colums :  Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'MedHouseVal'],
#       dtype='object')

# %%
print(" Generating Histogram ")
df.hist(bins=50, figsize=(20,15),edgecolor='black')
plt.suptitle("Histogram of neumaric features").figsize = 10
plt.show()
# Out:
#  Generating Histogram

# %%
print(" Generating BOX Plot ")
plt.figure(figsize=(14, 10))
for i,col in enumerate(df.columns):
    plt.subplot(3,3,i+1)
    sns.boxplot(y=df[col], color='skyblue')
    plt.title(col)
    plt.tight_layout()
plt.suptitle(" Box plot of neumarical features ")
plt.tight_layout()
plt.show()
# Out:
#  Generating BOX Plot

# %%
for col in df.columns:
    print(col)
# Out:
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# MedHouseVal

# %%
print(" Outlier Analysis ")
for col in df.columns:
    q1 = df[col].quantile(0.25)
    q2 = df[col].quantile(0.75)
    iqr = q2 - q1
    
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q2 + 1.5 * iqr
    
    lower_bound
    upper_bound
# Out:
#  Outlier Analysis
